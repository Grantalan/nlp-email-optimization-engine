# %%
# !pip install firecrawl-py pydantic

# %%
import os

# Replace with your actual Firecrawl API key
os.environ["FIRECRAWL_API_KEY"] = "fc-16adb0e8722c40b190b437c4359766ee"

# %%
from firecrawl import Firecrawl

app = Firecrawl()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitorPageDiff" shadows an attribute in parent "BaseModel"
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitorPageSnapshot" shadows an attribute in parent "BaseModel"
#   warnings.warn(

# %%
url = "https://reallygoodemails.com/categories/agency"
response = app.scrape(url, formats=["markdown"])

print(response.markdown)
# Out:
# ![RGE Studio](https://cdn.prod.website-files.com/6874d6dc18aa80cfe5e5f864/69e0b1458c7c8a3ff5207a76_rgestudio-a.webp)
#
# [Now you have zero excuses to NOT design really good emails. Introducing RGE Studio](https://reallygoodemails.com/school/blog/rge-studio-the-next-era)
#
# [Read more](https://reallygoodemails.com/school/blog/rge-studio-the-next-era)
#
# [![Really Good Emails](https://cdn.prod.website-files.com/6874d6dc18aa80cfe5e5f864/69d77af670cdee749bd2aab2_really-good-emails.svg)](https://reallygoodemails.com/)
#
# # The Best 121 Advertising/Marketing Agency Email Examples & Designs
#
# ...
